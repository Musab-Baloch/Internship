# %% [markdown]
# # Phase 2

# %% [markdown]
# ## Main Objectives
# - Prompt Engineering
# - Building APIs to control LLM behaviour
# - Improving response accuracy with RAGs and LANG CHAIN
# - Managing multiple AI agents
# - Training LLMs
# - Dataset manipulation
# - Learning MCPs and AI Workflow

# %% [markdown]
# ### Prompt Engineering
#
# -¬> [Primary Resourse](https://www.deeplearning.ai/courses/chatgpt-prompt-eng)

# %% [markdown]
# #### Notes
